# %%
import geodesic_dome as gd
import matplotlib.pyplot as plt
import pandas as pd

# %%
vertices, triangels, adj_list = gd.create_geodesic_dome(4)

# %%
print(vertices.shape)
# Out:
# (2562, 3)

# %%
fig, ax = plt.subplots(
    figsize=(15, 15), facecolor="None", subplot_kw={"projection": "3d"}
)

x = vertices[:, 0]
y = vertices[:, 1]
z = vertices[:, 2]
# ax.plot_wireframe(x, y, z, alpha=0.5)  # くり抜き曲面
ax.scatter(x, y, z, alpha=0.5)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
fig.suptitle("spherical surface", fontsize=10)
ax.set_aspect("equal")
plt.show()

# %%
fig, ax = plt.subplots(
    figsize=(15, 15), facecolor="None", subplot_kw={"projection": "3d"}
)
plt.gca().axis("off")
x = vertices[:, 0]
y = vertices[:, 1]
z = vertices[:, 2]
# ax.plot_wireframe(x, y, z, alpha=0.5)  # くり抜き曲面
ax.scatter(x, y, z, alpha=0.5)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
fig.suptitle("spherical surface", fontsize=10)
ax.set_aspect("equal")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# トーラスのパラメータ
R = 1  # トーラスの中心から軸までの距離
r = 0.3  # トーラスの断面円の半径
theta_res = 25  # 断面円の分割数
phi_res = 25  # 軸周りの分割数

# パラメータ値の生成
theta = np.linspace(0, 2 * np.pi, theta_res)
phi = np.linspace(0, 2 * np.pi, phi_res)
theta, phi = np.meshgrid(theta, phi)
c, a = R + r * np.cos(theta), r * np.sin(theta)

# トーラスの座標計算
x = c * np.cos(phi)
y = c * np.sin(phi)
z = a

# 三次元プロット
fig, ax = plt.subplots(
    figsize=(15, 15), facecolor="None", subplot_kw={"projection": "3d"}
)
plt.gca().axis("off")
ax.scatter(x, y, z, color="blue", alpha=0.5)
ax.plot_wireframe(x, y, z, color="blue", alpha=0.3)
ax.set_aspect("equal")

# グラフ表示
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# トーラスのパラメータ
R = 1  # トーラスの中心から軸までの距離
r = 0.3  # トーラスの断面円の半径
theta_res = 25  # 断面円の分割数
phi_res = 25  # 軸周りの分割数

# パラメータ値の生成
theta = np.linspace(0, 2 * np.pi, theta_res)
phi = np.linspace(0, 2 * np.pi, phi_res)
theta, phi = np.meshgrid(theta, phi)
c, a = R + r * np.cos(theta), r * np.sin(theta)

# トーラスの座標計算
x = c * np.cos(phi)
y = c * np.sin(phi)
z = a

# 三次元プロット
fig, ax = plt.subplots(
    figsize=(15, 15), facecolor="None", subplot_kw={"projection": "3d"}
)
plt.gca().axis("off")
ax.scatter(x, y, z, color="blue", alpha=0.3)
ax.set_aspect("equal")

# グラフ表示
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# トーラスのパラメータ
R = 1  # トーラスの中心から軸までの距離
r = 0.3  # トーラスの断面円の半径
theta_res = 50  # 断面円の分割数
phi_res = 50  # 軸周りの分割数

# パラメータ値の生成
theta = np.linspace(0, 2 * np.pi, theta_res)
phi = np.linspace(0, 2 * np.pi, phi_res)
theta, phi = np.meshgrid(theta, phi)
c, a = R + r * np.cos(theta), r * np.sin(theta)

# トーラスの座標計算
x = c * np.cos(phi)
y = c * np.sin(phi)
z = a

# 三次元プロット
fig, ax = plt.subplots(
    figsize=(15, 15), facecolor="None", subplot_kw={"projection": "3d"}
)
plt.gca().axis("off")
ax.scatter(x, y, z, color="blue", alpha=0.3)
ax.set_aspect("equal")

# グラフ表示
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# トーラスのパラメータ
R = 1  # トーラスの中心から軸までの距離
r = 0.3  # トーラスの断面円の半径
theta_res = 50  # 断面円の分割数
phi_res = 50  # 軸周りの分割数

# パラメータ値の生成
theta = np.linspace(0, 2 * np.pi, theta_res)
phi = np.linspace(0, 2 * np.pi, phi_res)
theta, phi = np.meshgrid(theta, phi)
c, a = R + r * np.cos(theta), r * np.sin(theta)

# トーラスの座標計算
x = c * np.cos(phi)
y = c * np.sin(phi)
z = a

# 三次元プロット
fig, ax = plt.subplots(
    figsize=(15, 15), facecolor="None", subplot_kw={"projection": "3d"}
)
plt.gca().axis("off")
ax.scatter(x, y, z, alpha=0.3)
ax.set_aspect("equal")

# グラフ表示
plt.show()

# %%
import geodesic_dome as gd
import matplotlib.pyplot as plt
import pandas as pd

# %%
vertices, triangels, adj_list = gd.create_geodesic_dome(1)

# %%
print(vertices.shape)
# Out:
# (42, 3)

# %%
fig, ax = plt.subplots(
    figsize=(15, 15), facecolor="None", subplot_kw={"projection": "3d"}
)
plt.gca().axis("off")
x = vertices[:, 0]
y = vertices[:, 1]
z = vertices[:, 2]
# ax.plot_wireframe(x, y, z, alpha=0.5)  # くり抜き曲面
ax.scatter(x, y, z, alpha=0.5)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
fig.suptitle("spherical surface", fontsize=10)
ax.set_aspect("equal")
plt.show()

# %%
import geodesic_dome as gd
import matplotlib.pyplot as plt
import pandas as pd

# %%
vertices, triangels, adj_list = gd.create_geodesic_dome(2)

# %%
print(vertices.shape)
# Out:
# (162, 3)

# %%
fig, ax = plt.subplots(
    figsize=(15, 15), facecolor="None", subplot_kw={"projection": "3d"}
)
plt.gca().axis("off")
x = vertices[:, 0]
y = vertices[:, 1]
z = vertices[:, 2]
# ax.plot_wireframe(x, y, z, alpha=0.5)  # くり抜き曲面
ax.scatter(x, y, z, alpha=0.5)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
fig.suptitle("spherical surface", fontsize=10)
ax.set_aspect("equal")
plt.show()

# %%
import geodesic_dome as gd
import matplotlib.pyplot as plt
import pandas as pd

# %%
vertices, triangels, adj_list = gd.create_geodesic_dome(3)

# %%
print(vertices.shape)
# Out:
# (642, 3)

# %%
fig, ax = plt.subplots(
    figsize=(15, 15), facecolor="None", subplot_kw={"projection": "3d"}
)
plt.gca().axis("off")
x = vertices[:, 0]
y = vertices[:, 1]
z = vertices[:, 2]
# ax.plot_wireframe(x, y, z, alpha=0.5)  # くり抜き曲面
ax.scatter(x, y, z, alpha=0.5)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
fig.suptitle("spherical surface", fontsize=10)
ax.set_aspect("equal")
plt.show()

# %%
# トーラスを平面に展開

x = np.arange(25)
y = np.arange(25)
X, Y = np.meshgrid(x, y)
fig, ax = plt.subplots(figsize=(15, 15), facecolor="None")
plt.gca().axis("off")
ax.plot_wireframe(X, Y, color="blue", alpha=0.8)
ax.scatter(X, Y, alpha=0.3, s=100)
ax.set_aspect("equal")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/sumthen/2023/python_2023/som/torus.py in line 9
#       <a href='file:///home/sumthen/2023/python_2023/som/torus.py?line=47'>48</a> fig, ax = plt.subplots(figsize=(15, 15), facecolor="None")
#       <a href='file:///home/sumthen/2023/python_2023/som/torus.py?line=48'>49</a> plt.gca().axis("off")
# ----> <a href='file:///home/sumthen/2023/python_2023/som/torus.py?line=49'>50</a> ax.plot_wireframe(X, Y, color="blue", alpha=0.8)
#      <a href='file:///home/sumthen/2023/python_2023/som/torus.py?line=50'>51</a> ax.scatter(X, Y, alpha=0.3, s=100)
#      <a href='file:///home/sumthen/2023/python_2023/som/torus.py?line=51'>52</a> ax.set_aspect("equal")
#
# AttributeError: 'Axes' object has no attribute 'plot_wireframe'

# %%
# トーラスを平面に展開

x = np.arange(25)
y = np.arange(25)
X, Y = np.meshgrid(x, y)
fig, ax = plt.subplots(figsize=(15, 15), facecolor="None")
plt.gca().axis("off")
ax.scatter(X, Y, alpha=0.3, s=100)
ax.set_aspect("equal")
plt.show()

# %%
# トーラスを平面に展開

x = np.arange(25)
y = np.arange(25)
X, Y = np.meshgrid(x, y)
fig, ax = plt.subplots(figsize=(15, 15), facecolor="None")
plt.gca().axis("off")
ax.scatter(X, Y, alpha=0.5, s=100)
ax.set_aspect("equal")
plt.show()

# %%
# トーラスを平面に展開

x = np.arange(25)
y = np.arange(25)
X, Y = np.meshgrid(x, y)
fig, ax = plt.subplots(figsize=(15, 15), facecolor="None")
plt.gca().axis("off")
ax.scatter(X, Y, alpha=1, s=100)
ax.set_aspect("equal")
plt.show()
